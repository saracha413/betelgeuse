# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

import os

import sys
print(sys.version)
# Out:
# 3.8.8 (default, Apr 13 2021, 12:59:45)
# [Clang 10.0.0 ]

# %%
def plot_variations(path):
    files = [path+f for f in os.listdir(path) if (os.path.isfile(os.path.join(path, f))) and (f.find('.DS') == -1) ]
    transits = [np.loadtxt(file, unpack=True, skiprows=2)[1] for file in files]
    #get modal fraction
    modals = [t/np.sum(t) for t in transits]
    
    wavelengths = np.loadtxt(files[0], unpack=True, skiprows=2)[0]
    
    suffix = '.txt'
    names = [(name.lstrip(path)).rstrip(suffix) for name in files]
    
    fig, axs = plt.subplots(2,4, sharex=True, sharey=True, figsize=(15,10))
    

    
    for i in range(len(transits)):
        if i<4:
            axs[0,i].plot(wavelengths,modals[i])
            axs[0,i].set_title(names[i])
        else:
            axs[1,i-4].plot(wavelengths,modals[i])
            axs[1,i-4].set_title(names[i])
            
    for ax in axs.flat:
        ax.set_xlabel('wavelengths(um)')
        ax.set_ylabel('modal fraction')
    
    #plt.legend()
    #plt.xlabel('wavelengths (um)')
    #plt.ylabel('Modal fraction')

# %%
jup_cloud_path = '/Users/saravannah/betelgeuse/single_param_jup_variants/jup_clouds/'
plot_variations(jup_cloud_path)

#varying cloud cover

# %%
jup_grav_path = '/Users/saravannah/betelgeuse/single_param_jup_variants/jup_grav/'
plot_variations(jup_grav_path)
plt.title('Varying surface gravity')
# Out:
# Text(0.5, 1.0, 'Varying surface gravity')

# %%
jup_planet_rad_path = '/Users/saravannah/betelgeuse/single_param_jup_variants/jup_planet_rad/'
plot_variations(jup_planet_rad_path)
plt.title('Varying planet radius')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-97-4d988630b88c> in <module>
#       1 jup_planet_rad_path = '/Users/saravannah/betelgeuse/single_param_jup_variants/jup_planet_rad/'
# ----> 2 plot_variations(jup_planet_rad_path)
#       3 plt.title('Varying planet radius')
#
# <ipython-input-93-34ae58e57812> in plot_variations(path)
#      19             axs[0,i].set_title(names[i])
#      20         else:
# ---> 21             axs[1,i-4].plot(wavelengths,modals[i])
#      22             axs[1,i-4].set_title(names[i])
#      23
#
# IndexError: index 4 is out of bounds for axis 1 with size 4

# %%
jup_rayleigh_path = '/Users/saravannah/betelgeuse/single_param_jup_variants/jup_rayleigh/'
plot_variations(jup_rayleigh_path)
plt.title('Varying Rayleigh scattering')
# Out:
# Text(0.5, 1.0, 'Varying Rayleigh scattering')

# %%
jup_star_rad_path = '/Users/saravannah/betelgeuse/single_param_jup_variants/jup_star_rad/'
plot_variations(jup_star_rad_path)
plt.title('Varying stellar radius')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-98-795600268410> in <module>
#       1 jup_star_rad_path = '/Users/saravannah/betelgeuse/single_param_jup_variants/jup_star_rad/'
# ----> 2 plot_variations(jup_star_rad_path)
#       3 plt.title('Varying stellar radius')
#
# <ipython-input-93-34ae58e57812> in plot_variations(path)
#      19             axs[0,i].set_title(names[i])
#      20         else:
# ---> 21             axs[1,i-4].plot(wavelengths,modals[i])
#      22             axs[1,i-4].set_title(names[i])
#      23
#
# IndexError: index 4 is out of bounds for axis 1 with size 4

# %%
jup_temp_path = '/Users/saravannah/betelgeuse/single_param_jup_variants/jup_temp/'
plot_variations(jup_temp_path)
plt.title('Varying equilibrium temperature')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-d67313995217> in <module>
#       1 jup_temp_path = '/Users/saravannah/betelgeuse/single_param_jup_variants/jup_temp/'
# ----> 2 plot_variations(jup_temp_path)
#       3 plt.title('Varying equilibrium temperature')
#
# <ipython-input-93-34ae58e57812> in plot_variations(path)
#      19             axs[0,i].set_title(names[i])
#      20         else:
# ---> 21             axs[1,i-4].plot(wavelengths,modals[i])
#      22             axs[1,i-4].set_title(names[i])
#      23
#
# IndexError: index 4 is out of bounds for axis 1 with size 4
